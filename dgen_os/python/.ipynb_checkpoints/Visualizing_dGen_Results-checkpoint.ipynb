# %% [markdown]
# ## Styling & Helper Functions

# %% [markdown]
# ## Import Packages
# If some packages fail then google 'conda install < package name >' or 'pip install < package name >'
#
# You can run 'conda install -c anaconda psycopg2' directly in a new cell or in your anaconda terminal

# %%
import psycopg2 as pg
import psycopg2.extras as pgx
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import matplotlib.ticker as mtick

import sqlalchemy
from sqlalchemy import create_engine
import pyarrow as pa
import pyarrow.parquet as pq
from IPython.display import HTML
import base64

from pylab import *
# %matplotlib inline
import geopandas as gpd

# %%
# *** Styling Block ***
fmt = '${x:,.0f}'
tick = mtick.StrMethodFormatter(fmt)
SMALL_SIZE = 14
MEDIUM_SIZE = 16
BIGGER_SIZE = 18
FIG_SIZE = (12,9) #change figure size throughout for non-faceted figures
plt.rc('font', size=SMALL_SIZE)          # controls default text sizes
plt.rc('axes', titlesize=BIGGER_SIZE)     # fontsize of the axes title
plt.rc('axes', labelsize=MEDIUM_SIZE)    # fontsize of the x and y labels
plt.rc('xtick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('ytick', labelsize=SMALL_SIZE)    # fontsize of the tick labels
plt.rc('legend', fontsize=SMALL_SIZE)    # legend fontsize
plt.rc('figure', titlesize=BIGGER_SIZE)  # fontsize of the figure title
sns.set_style('white')
cp = sns.color_palette() #color palette to use throughout 

def pull_data(sql,data,con):
    out = pd.DataFrame()
    for i,r in data.iterrows():
        sql_in = sql % (r['scenario'], r['schema'], r['year'])
        out = pd.concat([out, pd.read_sql(sql_in, con)])
    return out

# *** Helper function to easily download dataframes as csv files
def create_download_link( df, title = "Download CSV file", filename = "give_me_a_detailed_name.csv"):  
    csv = df.to_csv(index =True)
    b64 = base64.b64encode(csv.encode())
    payload = b64.decode()
    html = '<a download="{filename}" href="data:text/csv;base64,{payload}" target="_blank">{title}</a>'
    html = html.format(payload=payload,title=title,filename=filename)
    return HTML(html)

# %% [markdown]
# ## Connect to your specific database

# %%
x = 'dgen_db' # if you named your database something else then change the name here
engine = create_engine("postgresql+psycopg2://postgres:postgres@127.0.0.1:5432/{0}".format(x))
con = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     760         if not fairy:
# --> 761             fairy = _ConnectionRecord.checkout(pool)
#     762
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     361         if connect:
# --> 362             self.__connect()
#     363         self.finalize_callback = deque()
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     210         try:
# --> 211             raise exception
#     212         finally:
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#
# OperationalError: could not connect to server: Connection refused
# 	Is the server running on host "127.0.0.1" and accepting
# 	TCP/IP connections on port 5432?
#
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-21-c1639d6c6a39> in <module>
#       1 x = 'dgen_db' # if you named your database something else then change the name here
#       2 engine = create_engine("postgresql+psycopg2://postgres:postgres@127.0.0.1:5432/{0}".format(x))
# ----> 3 con = engine.connect()
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/base.py in connect(self, close_with_result)
#    3164         """
#    3165
# -> 3166         return self._connection_cls(self, close_with_result=close_with_result)
#    3167
#    3168     @util.deprecated(
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events, _allow_revalidate)
#      94                 connection
#      95                 if connection is not None
# ---> 96                 else engine.raw_connection()
#      97             )
#      98
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    3243
#    3244         """
# -> 3245         return self._wrap_pool_connect(self.pool.connect, _connection)
#    3246
#    3247
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
# -> 3215                 Connection._handle_dbapi_exception_noconnection(
#    3216                     e, dialect, self
#    3217                 )
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    2066             util.raise_(newraise, with_traceback=exc_info[2], from_=e)
#    2067         elif should_wrap:
# -> 2068             util.raise_(
#    2069                 sqlalchemy_exception, with_traceback=exc_info[2], from_=e
#    2070             )
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    3210         dialect = self.dialect
#    3211         try:
# -> 3212             return fn()
#    3213         except dialect.dbapi.Error as e:
#    3214             if connection is None:
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in connect(self)
#     299
#     300         """
# --> 301         return _ConnectionFairy._checkout(self)
#     302
#     303     def _return_conn(self, record):
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _checkout(cls, pool, threadconns, fairy)
#     759     def _checkout(cls, pool, threadconns=None, fairy=None):
#     760         if not fairy:
# --> 761             fairy = _ConnectionRecord.checkout(pool)
#     762
#     763             fairy._pool = pool
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in checkout(cls, pool)
#     417     @classmethod
#     418     def checkout(cls, pool):
# --> 419         rec = pool._do_get()
#     420         try:
#     421             dbapi_connection = rec.get_connection()
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     143             except:
#     144                 with util.safe_reraise():
# --> 145                     self._dec_overflow()
#     146         else:
#     147             return self._do_get()
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/impl.py in _do_get(self)
#     140         if self._inc_overflow():
#     141             try:
# --> 142                 return self._create_connection()
#     143             except:
#     144                 with util.safe_reraise():
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in _create_connection(self)
#     245         """Called by subclasses to create a new ConnectionRecord."""
#     246
# --> 247         return _ConnectionRecord(self)
#     248
#     249     def _invalidate(self, connection, exception=None, _checkin=True):
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __init__(self, pool, connect)
#     360         self.__pool = pool
#     361         if connect:
# --> 362             self.__connect()
#     363         self.finalize_callback = deque()
#     364
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     603         except Exception as e:
#     604             with util.safe_reraise():
# --> 605                 pool.logger.debug("Error on connect(): %s", e)
#     606         else:
#     607             # in SQLAlchemy 1.4 the first_connect event is not used by
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      68             self._exc_info = None  # remove potential circular references
#      69             if not self.warn_only:
# ---> 70                 compat.raise_(
#      71                     exc_value,
#      72                     with_traceback=exc_tb,
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/util/compat.py in raise_(***failed resolving arguments***)
#     209
#     210         try:
# --> 211             raise exception
#     212         finally:
#     213             # credit to
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/pool/base.py in __connect(self)
#     597         try:
#     598             self.starttime = time.time()
# --> 599             connection = pool._invoke_creator(self)
#     600             pool.logger.debug("Created new connection %r", connection)
#     601             self.connection = connection
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/create.py in connect(connection_record)
#     576                     if connection is not None:
#     577                         return connection
# --> 578             return dialect.connect(*cargs, **cparams)
#     579
#     580         creator = pop_kwarg("creator", connect)
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     582     def connect(self, *cargs, **cparams):
#     583         # inherits the docstring from interfaces.Dialect.connect
# --> 584         return self.dbapi.connect(*cargs, **cparams)
#     585
#     586     def create_connect_args(self, url):
#
# ~/Anaconda/anaconda3/envs/dg3n/lib/python3.8/site-packages/psycopg2/__init__.py in connect(dsn, connection_factory, cursor_factory, **kwargs)
#     124
#     125     dsn = _ext.make_dsn(dsn, **kwargs)
# --> 126     conn = _connect(dsn, connection_factory=connection_factory, **kwasync)
#     127     if cursor_factory is not None:
#     128         conn.cursor_factory = cursor_factory
#
# OperationalError: (psycopg2.OperationalError) could not connect to server: Connection refused
# 	Is the server running on host "127.0.0.1" and accepting
# 	TCP/IP connections on port 5432?
#
# (Background on this error at: http://sqlalche.me/e/14/e3q8)

# %% [markdown]
# #### Specify Databases to Load

# %%
res_schema = 'diffusion_results_20201026_162656657788_fina' # -- must input specific schema name here
com_schema = 'diffusion_results_20201027_101415409182_fina' # -- must input specific schema name here

# %% [markdown]
# #### Define SQL Queries

# %%
sql_res_in = '''
WITH a AS(
    SELECT *,'res_de'::text as scenario
    FROM %s.agent_outputs
)
SELECT SUM(system_kw_cum)/1e3 as deployment_mw,
SUM(developable_agent_weight*developable_roof_sqft) as sum_dev_roof_sqft,
AVG(payback_period) as payback,
AVG(system_kw) as system_size,
(SUM(developable_agent_weight*load_kwh_per_customer_in_bin::numeric))/1E9 as load_twh,
(SUM(system_kw_cum*8760*capacity_factor)/1E9) AS Cum_DPV_Gen_TWh,
year, sector_abbr, scenario
FROM a
WHERE state_abbr='%s' and sector_abbr='res' AND year<=2030
GROUP BY year, state_abbr, sector_abbr, scenario
ORDER BY year;'''%(res_schema, 'DE')
res_new = pd.read_sql(sql_res_in, con)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-13283e29556b> in <module>
#      15 GROUP BY year, state_abbr, sector_abbr, scenario
#      16 ORDER BY year;'''%(res_schema, 'DE')
# ---> 17 res_new = pd.read_sql(sql_res_in, con)
#
# NameError: name 'con' is not defined

# %%
sql_com_in = '''
WITH a AS(
    SELECT *,'com_de'::text as scenario
    FROM %s.agent_outputs
)
SELECT SUM(system_kw_cum)/1e3 as deployment_mw,
SUM(developable_agent_weight*developable_roof_sqft) as sum_dev_roof_sqft,
AVG(payback_period) as payback,
AVG(system_kw) as system_size,
(SUM(developable_agent_weight*load_kwh_per_customer_in_bin::numeric))/1E9 as load_twh,
(SUM(system_kw_cum*8760*capacity_factor)/1E9) AS Cum_DPV_Gen_TWh,
year, sector_abbr, scenario
FROM a
WHERE state_abbr='%s' and sector_abbr='com' AND year<=2030
GROUP BY year, state_abbr, sector_abbr, scenario
ORDER BY year;'''%(com_schema, 'DE')
com_new = pd.read_sql(sql_com_in, con)

# can also read csvs I saved directly in
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-1ed92e0fde3a> in <module>
#      15 GROUP BY year, state_abbr, sector_abbr, scenario
#      16 ORDER BY year;'''%(com_schema, 'DE')
# ---> 17 com_new = pd.read_sql(sql_com_in, con)
#      18
#      19 # can also read csvs I saved directly in
#
# NameError: name 'con' is not defined

# %% [markdown]
# #### Combine Queries DataFrames

# %%
comb_df = pd.concat([res_new, com_new])
comb_df
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-8e36c8f53c2d> in <module>
# ----> 1 comb_df = pd.concat([res_new, com_new])
#       2 comb_df
#
# NameError: name 'res_new' is not defined

# %%
pair_columns = ['scenario','payback','deployment_mw','load_twh']
pair_df = comb_df
pair_df = pair_df[pair_columns]

fg = sns.PairGrid(pair_df, hue='scenario')
fg = fg.map_diag(sns.distplot)
fg = fg.map_upper(plt.scatter, s=250, alpha = 0.2) #upper size is variable based on pv_MW_cum
fg = fg.map_lower(plt.scatter, s=40, alpha = 0.2) #lower size is fixed
fg = fg.add_legend()

plt.subplots_adjust(top=0.9)
fg.fig.suptitle('Pair Plots for Quick Summary')

fg.axes[0,0].set_ylim(0,30)
fg.axes[0,0].set_xlim(0,30)
fg.axes[1,1].set_ylim(0,160)
fg.axes[1,1].set_xlim(0,160)
fg.axes[2,2].set_ylim(0,8)
fg.axes[2,2].set_xlim(0,8)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-b278eafd5e4e> in <module>
#       1 pair_columns = ['scenario','payback','deployment_mw','load_twh']
# ----> 2 pair_df = comb_df
#       3 pair_df = pair_df[pair_columns]
#       4
#       5 fg = sns.PairGrid(pair_df, hue='scenario')
#
# NameError: name 'comb_df' is not defined

# %% [markdown]
# #### Format DataFrames

# %%
df_sys_size = comb_df.pivot_table(values = 'system_size', index = 'year', columns = ['scenario']).reset_index()
df_sys_size
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-3344b174e4fd> in <module>
# ----> 1 df_sys_size = comb_df.pivot_table(values = 'system_size', index = 'year', columns = ['scenario']).reset_index()
#       2 df_sys_size
#
# NameError: name 'comb_df' is not defined

# %%
df_payback = comb_df.pivot_table(values = 'payback', index = 'year', columns = ['scenario']).reset_index()
df_payback
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-16-066c1e9dc703> in <module>
# ----> 1 df_payback = comb_df.pivot_table(values = 'payback', index = 'year', columns = ['scenario']).reset_index()
#       2 df_payback
#
# NameError: name 'comb_df' is not defined

# %%
df_deployment = comb_df.pivot_table(values = 'deployment_mw', index = 'year', columns = ['scenario']).reset_index()
df_deployment
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-51aba6f23e41> in <module>
# ----> 1 df_deployment = comb_df.pivot_table(values = 'deployment_mw', index = 'year', columns = ['scenario']).reset_index()
#       2 df_deployment
#
# NameError: name 'comb_df' is not defined

# %%
df3 = df_deployment
df4 = df_sys_size
df5 = df_payback
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-95b18a51d3d1> in <module>
# ----> 1 df3 = df_deployment
#       2 df4 = df_sys_size
#       3 df5 = df_payback
#
# NameError: name 'df_deployment' is not defined

# %% [markdown]
# #### Deployment

# %%
plt.figure(figsize = (9,4))
ax = plt.subplot(111)
chartBox = ax.get_position()

ax.plot('year','res_de', data = df3, linestyle = '--', linewidth = 1.5, color = 'C0')
ax.plot('year','com_de', data = df3, linestyle = '--', linewidth = 1.5, color = 'C1')

plt.xlabel('Year', fontweight='bold')
plt.ylabel('Cumulative Deployment ($MW_{AC}$)', fontweight='bold')
plt.xlim(2013.5,2030.5)
plt.xticks(np.arange(2014, 2030, 2))
plt.ylim(0,160)
ax.yaxis.grid(True, color='#7e7e7e', linestyle=':')
ax.set_position([chartBox.x0, chartBox.y0, chartBox.width*0.6, chartBox.height])
ax.legend(loc='upper center', bbox_to_anchor=(1.27, 0.8), shadow=True, ncol=1)

# %% [markdown]
# #### System Size

# %%
plt.figure(figsize = (9,4))
ax = plt.subplot(111)
chartBox = ax.get_position()

ax.plot('year','res_de', data = df4, linestyle = '--', linewidth = 1.5, color = 'C0')
ax.plot('year','com_de', data = df4, linestyle = '--', linewidth = 1.5, color = 'C1')

plt.xlabel('Year', fontweight='bold')
plt.ylabel('Average System Size($KW_{AC}$)', fontweight='bold')
plt.xlim(2013.5,2030.5)
plt.xticks(np.arange(2014, 2030, 2))
plt.ylim(0,230)
ax.yaxis.grid(True, color='#7e7e7e', linestyle=':')
ax.set_position([chartBox.x0, chartBox.y0, chartBox.width*0.6, chartBox.height])
ax.legend(loc='upper center', bbox_to_anchor=(1.27, 0.8), shadow=True, ncol=1)

# %% [markdown]
# #### Payback Period

# %%
plt.figure(figsize = (9,4))
ax = plt.subplot(111)
chartBox = ax.get_position()

ax.plot('year','res_de', data = df5, linestyle = '--', linewidth = 1.5, color = 'C0')
ax.plot('year','com_de', data = df5, linestyle = '--', linewidth = 1.5, color = 'C1')

plt.xlabel('Year', fontweight='bold')
plt.ylabel('Average Payback Period (yrs)', fontweight='bold')
plt.xlim(2013.5,2030.5)
plt.xticks(np.arange(2014, 2030, 2))
plt.ylim(0,30)
ax.yaxis.grid(True, color='#7e7e7e', linestyle=':')
ax.set_position([chartBox.x0, chartBox.y0, chartBox.width*0.6, chartBox.height])
ax.legend(loc='upper center', bbox_to_anchor=(1.27, 0.8), shadow=True, ncol=1)
